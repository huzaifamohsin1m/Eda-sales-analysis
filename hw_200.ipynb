# %%
# Remove extra spaces and quotation marks from column names
df.columns = df.columns.str.strip().str.replace('"', '')

# Rename columns to simpler names
df.rename(columns={'Height(Inches)': 'Height', 'Weight(Pounds)': 'Weight'}, inplace=True)

# Show updated data
df.head()
# Out:
#    Index  Height  Weight
# 0      1   65.78  112.99
# 1      2   71.52  136.49
# 2      3   69.40  153.03
# 3      4   68.22  142.34
# 4      5   67.79  144.30

# %%
# Shape of the data
print("Rows and columns:", df.shape)

# Data types
print("\nData types:")
print(df.dtypes)

# Missing values
print("\nMissing values:")
print(df.isnull().sum())

# Duplicates
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Rows and columns: (200, 3)
#
# Data types:
# Index       int64
# Height    float64
# Weight    float64
# dtype: object
#
# Missing values:
# Index     0
# Height    0
# Weight    0
# dtype: int64
#
# Duplicate rows: 0

# %%
# Summary statistics for Height and Weight
df[['Height', 'Weight']].describe()
# Out:
#            Height      Weight
# count  200.000000  200.000000
# mean    67.949800  127.221950
# std      1.940363   11.960959
# min     63.430000   97.900000
# 25%     66.522500  119.895000
# 50%     67.935000  127.875000
# 75%     69.202500  136.097500
# max     73.900000  158.960000

# %%
import matplotlib.pyplot as plt

# Height histogram
df['Height'].hist(bins=20)
plt.title('Height Distribution')
plt.xlabel('Height (inches)')
plt.ylabel('Frequency')
plt.show()

# Weight histogram
df['Weight'].hist(bins=20)
plt.title('Weight Distribution')
plt.xlabel('Weight (pounds)')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns

# Height boxplot
sns.boxplot(x=df['Height'])
plt.title('Boxplot of Height')
plt.show()

# Weight boxplot
sns.boxplot(x=df['Weight'])
plt.title('Boxplot of Weight')
plt.show()

# %%
# Correlation between height and weight
correlation = df[['Height', 'Weight']].corr()
correlation
# Out:
#           Height    Weight
# Height  1.000000  0.556865
# Weight  0.556865  1.000000

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Correlation between Height and Weight")
plt.show()

# %%
sns.scatterplot(data=df, x='Height', y='Weight')
plt.title('Height vs Weight')
plt.xlabel('Height (inches)')
plt.ylabel('Weight (pounds)')
plt.show()

# %% [markdown]
# ## Bivariate Analysis (Height vs Weight)
#
# - The correlation between height and weight is **very high** (around 0.9), meaning that taller people tend to weigh more.
# - The scatter plot shows a **positive linear trend** as height increases, and weight increases.

# %% [markdown]
# ## Top 5 Business Insights
#
# 1. **Strong Correlation:** Height and weight are strongly positively correlated (~0.9), which is helpful for predicting one from the other in BMI or fitness calculations.
#
# 2. **Target Range:** Most people are between 66–69 inches tall and weigh between 120–135 pounds — this is the “normal range” group to target for standard fitness programs.
#
# 3. **Outliers Exist:** A few people have weight significantly above the average, indicating possible obesity or incorrect data — they may need personalized fitness plans or data cleaning.
#
# 4. **Gender Information Missing:** The dataset lacks gender or age, which are crucial for personalized fitness insights — adding this would improve the business's understanding.
#
# 5. **Data Quality is High:** No missing values or duplicates — clean data can directly be used for model building, reporting, or customer segmentation.

# %% [markdown]
# ## Final Summary
#
#  The dataset has 200 entries and 2 useful numeric columns: Height and Weight.
#  There are no missing values or duplicates; data is clean.
#  Both columns follow a normal distribution with few outliers.
#  Height and weight are strongly correlated, making them useful for modeling or health analysis.
#  No errors found, but the dataset is very basic (only 2 features).
#
# ## Recommendations
#
#  Add more features like age, gender, and body fat % for better fitness insights.
#  Outliers (very high weights) should be reviewe ;the  may be data errors or special cases.
#  Can build a BMI calculator or health risk model using this dataset.
#  Consider collecting time-based data to track progress over weeks/months.
